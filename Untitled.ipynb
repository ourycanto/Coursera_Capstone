# %%
import pandas as pd

# %%
df = pd.read_excel('Titanic2.xls')

# %%
df.head()
# Out:
#   Survived Passenger Class                                             Name  \
# 0      Yes           First                    Allen, Miss. Elisabeth Walton
# 1      Yes           First                   Allison, Master. Hudson Trevor
# 2       No           First                     Allison, Miss. Helen Loraine
# 3       No           First             Allison, Mr. Hudson Joshua Creighton
# 4       No           First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       Sex      Age  No of Siblings or Spouses on Board  \
# 0  Female  29.0000                                   0
# 1    Male   0.9167                                   1
# 2  Female   2.0000                                   1
# 3    Male  30.0000                                   1
# 4  Female  25.0000                                   1
#
#    No of Parents or Children on Board Ticket Number  Passenger Fare    Cabin  \
# 0                                   0         24160        211.3375       B5
# ...

# %%
df2 = pd.read_csv('titanic.csv')

# %%
df2.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
import matplotlib.pyplot as plt

transparency = 0.35 
area_df.plot(kind='area', alpha=transparency, figsize=(20, 10))

plt.title('Plot Title')
plt.ylabel('Vertical Axis Label')
plt.xlabel('Horizontal Axis Label')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-34506dd5f436> in <module>
#       2
#       3 transparency = 0.35
# ----> 4 area_df.plot(kind='area', alpha=transparency, figsize=(20, 10))
#       5
#       6 plt.title('Plot Title')
#
# NameError: name 'area_df' is not defined
